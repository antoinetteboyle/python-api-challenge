# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import datetime
import time

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vac_df = pd.read_csv("../../output_data/cityweather_data.csv")
vac_df.head()
# Out:
#              City      Lat       Lng  Max temp    Temp  Humidity  Cloudiness  \
# 0         Kavieng  -2.5744  150.7967     80.69   80.69        82         100
# 1  Saint-Philippe -21.3585   55.7679     86.11   83.97        72          16
# 2          Yulara -25.2406  130.9889    109.24  109.24         8          15
# 3        Hermanus -34.4187   19.2345     89.91   78.80        42          10
# 4        Khatanga  71.9667  102.5000    -39.32  -39.32       100          65
#
#    Windspeed Country        Date
# 0       7.56      PG  1639820794
# 1       2.01      RE  1639821072
# 2      10.36      AU  1639820871
# 3      13.42      ZA  1639821073
# 4       3.13      RU  1639820909

# %%
vac_df.shape
# Out:
# (541, 10)

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Store latitude and longitude in locations
vlocations = vac_df[["Lat","Lng"]]

# %%
# Store humidity weight values and convert to float
hum = vac_df["Humidity"].astype(float)
hum
# Out:
# 0       82.0
# 1       72.0
# 2        8.0
# 3       42.0
# 4      100.0
#        ...
# 536     33.0
# 537     99.0
# 538    100.0
# 539     75.0
# 540     62.0
# Name: Humidity, Length: 541, dtype: float64

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(vlocations, weights=hum, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=5)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# * Narrow down the DataFrame to find your ideal weather condition. For example:
# * A max temperature lower than 80 degrees but higher than 70.
# * Wind speed less than 10 mph.
# * Zero cloudiness.
# * Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
# * **Note:** Feel free to adjust to your specifications but be sure to limit the number of rows returned by your API requests to a reasonable number.

# %%
Tindex = vac_df[(vac_df['Max temp']>=70) & (vac_df['Max temp']<=80) & (vac_df['Windspeed']<=10) & (vac_df['Cloudiness']<=0)].index
Tindex
# Out:
# Int64Index([28, 82, 186, 296, 307, 328, 362, 491, 503], dtype='int64')

# %%
hotel_df = vac_df.drop(Tindex,inplace=False)
hotel_df
# Out:
#                City      Lat       Lng  Max temp    Temp  Humidity  \
# 0           Kavieng  -2.5744  150.7967     80.69   80.69        82
# 1    Saint-Philippe -21.3585   55.7679     86.11   83.97        72
# 2            Yulara -25.2406  130.9889    109.24  109.24         8
# 3          Hermanus -34.4187   19.2345     89.91   78.80        42
# 4          Khatanga  71.9667  102.5000    -39.32  -39.32       100
# ..              ...      ...       ...       ...     ...       ...
# 536        Saryozek  44.3583   77.9753     40.93   40.93        33
# 537   Batagay-Alyta  67.8006  130.4114    -23.31  -23.31        99
# 538        Morehead  37.2711  -87.1764     58.98   52.92       100
# 539       Belyy Yar  53.6039   91.3903     33.69   29.86        75
# 540            Kyra  49.5776  111.9753      6.80    6.80        62
#
#      Cloudiness  Windspeed Country        Date
# 0           100       7.56      PG  1639820794
# 1            16       2.01      RE  1639821072
# 2            15      10.36      AU  1639820871
# 3            10      13.42      ZA  1639821073
# 4            65       3.13      RU  1639820909
# ..          ...        ...     ...         ...
# 536          64       3.04      KZ  1639821777
# 537         100       1.39      RU  1639821777
# 538          90       0.00      US  1639821777
# 539           0      11.18      RU  1639821778
# 540         100       3.09      RU  1639821778
#
# [532 rows x 10 columns]

# %% [markdown]
# # Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#              City      Lat       Lng  Max temp    Temp  Humidity  Cloudiness  \
# 0         Kavieng  -2.5744  150.7967     80.69   80.69        82         100
# 1  Saint-Philippe -21.3585   55.7679     86.11   83.97        72          16
# 2          Yulara -25.2406  130.9889    109.24  109.24         8          15
# 3        Hermanus -34.4187   19.2345     89.91   78.80        42          10
# 4        Khatanga  71.9667  102.5000    -39.32  -39.32       100          65
#
#    Windspeed Country        Date Hotel Name
# 0       7.56      PG  1639820794
# 1       2.01      RE  1639821072
# 2      10.36      AU  1639820871
# 3      13.42      ZA  1639821073
# 4       3.13      RU  1639820909

# %%
# params dictionary to update each iteration

params = {
    "radius": 5000,
    "types": "hotel",
    "key": g_key
}
               
# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    
        # get lat, lng from df
        lat = row["Lat"]
        lng = row["Lng"]
        city = row["City"]
        # change location each iteration while leaving original params in place
        params["location"] = f"{lat},{lng}"
        
        #print(f"Retrieving nearest Hotel to City {index}: {city}.")
        # Use the search term: "hotel" and our lat/lng
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        response = requests.get(base_url, params=params)
        name_hotel = response.json()
        # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
        try:
            print(f"{index} Closest {city} hotel is {name_hotel['results'][0]['name']}.")
            hotel_df.loc[index, "Hotel Name"] = name_hotel['results'][0]["name"]
        except (KeyError, IndexError):
            print(f"Missing field...skipping {index} {city}")
            pass
# Out:
# 0 Closest Kavieng hotel is Kavieng.
# 1 Closest Saint-Philippe hotel is Saint-Philippe.
# 2 Closest Yulara hotel is Petermann.
# 3 Closest Hermanus hotel is Hermanus.
# 4 Closest Khatanga hotel is Chatanga.
# 5 Closest Trstená hotel is Trstená.
# 6 Closest Takaungu hotel is Kilifi.
# 7 Closest Mataura hotel is Gore.
# 8 Closest Saint Paul Harbor hotel is Kodiak.
# 9 Closest Newport hotel is Newport.
# 10 Closest Melilla hotel is Melilla.
# 11 Closest Punta Arenas hotel is Punta Arenas.
# 12 Closest Aklavik hotel is Aklavik.
# 13 Closest Carnot hotel is Carnot.
# 14 Closest Chui hotel is Chuy.
# 15 Closest Hithadhoo hotel is Addu City.
# 16 Closest Guane hotel is Guane.
# 17 Closest Salinópolis hotel is Salinópolis.
# 18 Closest Vaini hotel is Nukuhetulu.
# 19 Closest Bethel hotel is Danbury.
# 20 Closest Rikitea hotel is Rikitea.
# 21 Closest Tirukkoyilur hotel is Thirukoilure.
# 22 Closest Geraldton hotel is Geraldton.
# 23 Closest Avarua hotel is Avarua District.
# 24 Closest Batouri hotel is Batouri.
# 25 Closest Fortuna hotel is Fortuna.
# 26 Closest Rājula hotel is Rajula.
# 27 Closest Ushuaia hotel is Ushuaia.
# 29 Closest Tessalit hotel is Achemelmel.
# 30 Closest Jamestown hotel is Jamestown.
# 31 Closest Talara hotel is Talara.
# 32 Closest Mar del Plata hotel is Mar del Plata.
# 33 Closest Guerrero Negro hotel is Guerrero Negro.
# 34 Closest Carnarvon hotel is Carnarvon.
# 35 Closest Airai hotel is Atsabe.
# 36 Closest Albany hotel is Voorheesville.
# 37 Closest Vila Velha hotel is Vila Velha.
# 38 Closest Qaanaaq hotel is Qaanaaq.
# 39 Closest Busselton hotel is Busselton.
# 40 Closest Kirakira hotel is Arohane.
# 41 Closest Shingū hotel is Shingu.
# 42 Closest Boyuibe hotel is Boyuibe.
# 43 Closest Hualmay hotel is Huacho.
# 44 Closest Broken Hill hotel is Broken Hill.
# 45 Closest Barrow hotel is Utqiagvik.
# 46 Closest Quime hotel is Quime.
# 47 Closest Yellowknife hotel is Yellowknife.
# 48 Closest Bredasdorp hotel is Bredasdorp.
# 49 Closest Nemuro hotel is Nemuro.
# 50 Closest Faanui hotel is Vaitape.
# 51 Closest Bamako hotel is Bamako.
# 52 Closest Nanortalik hotel is Nanortalik.
# 53 Closest Lebu hotel is Lebu.
# 54 Closest Barcelona hotel is Barcelona.
# 55 Closest Shawinigan hotel is Shawinigan.
# 56 Closest Hobart hotel is Hobart.
# 57 Closest La Providencia hotel is Cuauhtémoc.
# 58 Closest Nara hotel is Nara.
# 59 Closest Tautira hotel is Tautira.
# 60 Closest Sambalpur hotel is Sambalpur.
# 61 Closest Bambous Virieux hotel is Vieux Grand Port.
# 62 Closest Cape Town hotel is Cape Town.
# 63 Closest Schleswig hotel is Schleswig.
# 64 Closest Acapulco de Juárez hotel is Acapulco.
# 65 Closest Butaritari hotel is Ukiangang.
# 66 Closest Rocha hotel is Rocha.
# 67 Closest Iqaluit hotel is Iqaluit.
# 68 Closest Leningradskiy hotel is Leningradsky.
# 69 Closest Puerto Ayora hotel is Puerto Ayora.
# 70 Closest Dandong hotel is Sinuiju.
# 71 Closest Manzhouli hotel is Hulunbuir.
# 72 Closest Port Alfred hotel is Port Alfred.
# 73 Closest Grand Island hotel is Grand Island.
# 74 Closest Bluff hotel is Bluff.
# 75 Closest Dikson hotel is Dikson.
# 76 Closest Coos Bay hotel is Coos Bay.
# 77 Closest Samarai hotel is Magesina.
# 78 Closest Lorengau hotel is Lorengau.
# 79 Closest Tuktoyaktuk hotel is Tuktoyaktuk.
# 80 Closest Cabo San Lucas hotel is Cabo San Lucas.
# 81 Closest Tromsø hotel is Tromsø.
# 83 Closest Krasnosel'kup hotel is Krasnosel'kup.
# 84 Closest Inhambane hotel is Maxixe.
# 85 Closest Longonjo hotel is Longonjo.
# 86 Closest Ribeira Grande hotel is Horta.
# 87 Closest Clyde River hotel is Clyde River.
# 88 Closest Nikolskoye hotel is Saint Petersburg.
# 89 Closest Liberty hotel is Midway.
# 90 Closest Hamilton hotel is Cincinnati.
# 91 Closest Husavik hotel is Húsavík.
# 92 Closest Biak hotel is CV. MEGA RENTAL Mobil Luwuk Banggai.
# 93 Closest Port-Cartier hotel is Port-Cartier.
# 94 Closest Kapaa hotel is Kapaʻa.
# 95 Closest Atuona hotel is Atuona.
# 96 Closest Khurai hotel is Khurai.
# 97 Closest Rincon hotel is Rincon.
# 98 Closest Phibun Mangsahan hotel is Phibun.
# 99 Closest Constitución hotel is Constitución.
# 100 Closest Cartagena del Chairá hotel is Cartagena del Chairá.
# 101 Closest Aswān hotel is Aswan.
# 102 Closest São Filipe hotel is Sao Filipe.
# 103 Closest Wamba hotel is Wamba.
# 104 Closest Auki hotel is Auki.
# 105 Closest Nome hotel is Nome.
# 106 Closest Umm Kaddadah hotel is Umm Kadadda.
# 107 Closest Hasaki hotel is Kamisu.
# 108 Closest Meulaboh hotel is Meulaboh.
# 109 Closest Mount Gambier hotel is Mount Gambier.
# 110 Closest Provideniya hotel is Provideniya.
# 111 Closest Saldanha hotel is Saldanha.
# 112 Closest Blagoyevo hotel is Ust'-Vacherga.
# 113 Closest Lødingen hotel is Lodingen.
# 114 Closest Novo Cruzeiro hotel is Novo Cruzeiro.
# 115 Closest San Patricio hotel is Sinton.
# 116 Closest Stalida hotel is Malia, Crete.
# 117 Closest Esperance hotel is Esperance.
# 118 Closest Havre-St-Pierre hotel is Havre-Saint-Pierre.
# 119 Closest Ust-Maya hotel is Ust'-Maya.
# 120 Closest Peleduy hotel is Peledui.
# 121 Closest George Town hotel is George Town.
# 122 Closest Wichita Falls hotel is Wichita Falls.
# 123 Closest Mehamn hotel is Mehamn.
# 124 Closest Sembabule hotel is Sembabule.
# 125 Closest Ilanskiy hotel is Ilansky.
# 126 Closest Saskylakh hotel is Saskylakh.
# 127 Closest Manavālakurichi hotel is Vellimalai.
# 128 Closest Chokurdakh hotel is Chokurdakh.
# 129 Closest San Juan hotel is San Juan.
# 130 Closest Katsuura hotel is Katsuura.
# 131 Closest Preobrazheniye hotel is Preobrazheniye.
# 132 Closest Wau hotel is Wau.
# 133 Closest Lucapa hotel is Lucapa.
# 134 Closest Port Elizabeth hotel is Gqeberha.
# 135 Closest Nizhniy Kuranakh hotel is Nizhnii Kuranakh.
# 136 Closest Uíge hotel is Uige.
# 137 Closest Shache hotel is Kashgar Prefecture.
# 138 Closest Karratha hotel is Karratha.
# 139 Closest Saint-François hotel is Molinet.
# 140 Closest Tiksi hotel is Tiksi.
# 141 Closest Chinsali hotel is Chinsali.
# 142 Closest Tikhvin hotel is Tikhvin.
# 143 Closest San Cristobal hotel is San Cristobal.
# 144 Closest Eureka hotel is Eureka.
# 145 Closest Camaçari hotel is Camaçari.
# 146 Closest Vilhena hotel is Vilhena.
# 147 Closest Tezu hotel is Tezu.
# 148 Closest Yangi Marg`ilon hotel is Fergana.
# 149 Closest New Norfolk hotel is New Norfolk.
# 150 Closest Dhidhdhoo hotel is Dhidhdhoo.
# 151 Closest Tomatlán hotel is Tomatlán.
# 152 Closest Ukiah hotel is Ukiah.
# 153 Closest Panama City hotel is Panama City.
# 154 Closest Mariehamn hotel is Mariehamn.
# 155 Closest Pevek hotel is Pevek.
# 156 Closest Mayumba hotel is Mayumba.
# 157 Closest Beringovskiy hotel is Beringovskii.
# 158 Closest Poum hotel is Poum.
# 159 Closest Sayyan hotel is Sayyan.
# 160 Closest Suntar hotel is Suntar.
# 161 Closest São João da Barra hotel is Grussaí.
# 162 Closest Sambava hotel is Sambava.
# 163 Closest Carutapera hotel is Carutapera.
# 164 Closest Zhigansk hotel is Zhigansk.
# 165 Closest Vătava hotel is Vătava.
# 166 Closest Mackay hotel is Mackay.
# 167 Closest Hilo hotel is Hilo.
# 168 Closest Ban Nahin hotel is Nam Dua.
# 169 Closest Hofn hotel is Höfn.
# 170 Closest São José da Coroa Grande hotel is São José da Coroa Grande.
# 171 Closest Tasiilaq hotel is Tasiilaq.
# 172 Closest Boysun hotel is Baysun.
# 173 Closest Coyhaique hotel is Coyhaique.
# Missing field...skipping 174 Boende
# 175 Closest Upernavik hotel is Upernavik.
# 176 Closest Raudeberg hotel is Måløy.
# 177 Closest Kautokeino hotel is Kautokeino.
# 178 Closest Narsaq hotel is Narsaq.
# 179 Closest Christchurch hotel is Christchurch.
# 180 Closest Bela Vista hotel is Bela Vista.
# 181 Closest Norman Wells hotel is Norman Wells.
# 182 Closest Thompson hotel is Thompson.
# 183 Closest Berlevåg hotel is Berlevåg.
# 184 Closest Batemans Bay hotel is Batemans Bay.
# 185 Closest Pisco hotel is Pisco.
# 187 Closest Tacna hotel is Tacna.
# 188 Closest Ulaanbaatar hotel is Ulaanbaatar.
# 189 Closest Pacific Grove hotel is Monterey.
# 190 Closest Codrington hotel is Yambuk.
# 191 Closest Caramay hotel is Roxas.
# 192 Closest Casablanca hotel is Casablanca.
# 193 Closest Richards Bay hotel is Richards Bay.
# 194 Closest Vestmannaeyjar hotel is Vestmannaeyjar.
# 195 Closest Tilichiki hotel is Tilichiki.
# 196 Closest Hirara hotel is Hirara.
# 197 Closest Antofagasta hotel is Antofagasta.
# 198 Closest Severo-Kuril'sk hotel is Severo-Kurilsk.
# 199 Closest Evanston hotel is Evanston.
# 200 Closest Gebre Guracha hotel is Gebre Guracha.
# 201 Closest Zhalantun hotel is Hulunbuir.
# 202 Closest Sept-Îles hotel is Sept-Iles.
# 203 Closest Mackenzie hotel is Mackenzie Airport (YZY).
# 204 Closest Ilulissat hotel is Ilulissat.
# 205 Closest Tual hotel is Tual.
# 206 Closest Bouaké hotel is Bouake.
# 207 Closest Shimanovsk hotel is Shimanovsk.
# 208 Closest Ancud hotel is Ancud.
# Missing field...skipping 209 Adrar
# 210 Closest Portland hotel is Portland.
# 211 Closest Bathsheba hotel is Wilson Hill.
# 212 Closest ‘Āhuimanu hotel is Honolulu.
# 213 Closest Korem hotel is Korem.
# 214 Closest Cidreira hotel is CIDREIRA.
# 215 Closest Nandikotkūr hotel is Nandikotkur.
# 216 Closest Sarangani hotel is Municipality of Sarangani.
# 217 Closest Ikongo hotel is Fort-Carnot.
# 218 Closest La Ronge hotel is La Ronge.
# 219 Closest Alakurtti hotel is Alakurtti.
# 220 Closest Ballina hotel is Ballina.
# 221 Closest Port Hedland hotel is Port Hedland.
# 222 Closest Pathein hotel is Pathein.
# 223 Closest Sitka hotel is Sitka.
# 224 Closest Lafiagi hotel is Lafiagi.
# 225 Closest Turaif hotel is Turaif.
# 226 Closest Kaitangata hotel is Kaitangata.
# 227 Closest Kavaratti hotel is Kavaratti.
# 228 Closest Tura hotel is Tura.
# 229 Closest Basoko hotel is Basoko.
# 230 Closest Tokur hotel is Tokur.
# 231 Closest Yaan hotel is Iorjan.
# 232 Closest Fort Nelson hotel is Fort Nelson.
# 233 Closest Bougouni hotel is Bougouni.
# 234 Closest Nishifukuma hotel is Fukutsu.
# 235 Closest Kapit hotel is Kapit.
# 236 Closest Bagacay hotel is Sorsogon City.
# 237 Closest Hokitika hotel is Hokitika.
# 238 Closest Baykit hotel is Baikit.
# 239 Closest Yangshe hotel is Suzhou.
# 240 Closest East London hotel is East London.
# 241 Closest Shambu hotel is Shambu.
# 242 Closest Waingapu hotel is Waingapu.
# 243 Closest Griffith hotel is Gary.
# 244 Closest Muisne hotel is Muisne.
# 245 Closest Tortosa hotel is Tortosa.
# 246 Closest Urucará hotel is Urucará.
# 247 Closest Marivan hotel is Mariwan.
# 248 Closest Kawardha hotel is Kawardha.
# 249 Closest Belmonte hotel is Belmonte.
# 250 Closest Hede hotel is Yancheng.
# 251 Closest Tacuarembó hotel is Tacuarembo.
# 252 Closest Marrakesh hotel is Marrakesh.
# 253 Closest Laiyang hotel is Yantai.
# 254 Closest Jacareacanga hotel is Jacareacanga.
# 255 Closest Macaé hotel is Macaé.
# 256 Closest Cockburn Town hotel is Cockburn Town.
# 257 Closest Isa Khel hotel is Kunduz.
# 258 Closest Pinsk hotel is Pinsk.
# 259 Closest Holland hotel is Holland.
# 260 Closest Lüderitz hotel is Luderitz.
# 261 Closest Vila Praia de Âncora hotel is Caminha.
# 262 Closest Diedorf hotel is Augsburg.
# 263 Closest Dali hotel is Dali.
# 264 Closest Lavrentiya hotel is Lavrentiya.
# 265 Closest Opuwo hotel is Opuwo.
# 266 Closest Yumen hotel is Jiuquan.
# 267 Closest Ingham hotel is Mason.
# 268 Closest Am Timan hotel is Am Timan.
# 269 Closest Yanam hotel is Yanam.
# 270 Closest Soller hotel is Sóller.
# 271 Closest Spirit River hotel is Spirit River.
# 272 Closest Aykhal hotel is Aikhal.
# 273 Closest Cabedelo hotel is Cabedelo.
# 274 Closest Nioro hotel is Nioro.
# 275 Closest Damietta hotel is Damietta.
# 276 Closest Wiesmoor hotel is Wiesmoor.
# 277 Closest Saint George hotel is St. George.
# 278 Closest Horodnytsya hotel is Horodnytsya.
# 279 Closest Westport hotel is Norwalk.
# 280 Closest Banda Aceh hotel is Banda Aceh.
# 281 Closest Mount Isa hotel is Mount Isa.
# 282 Closest San Fernando del Valle de Catamarca hotel is Catamarca.
# 283 Closest Avera hotel is Avera.
# 284 Closest Mingora hotel is Swat.
# 285 Closest Progreso hotel is Progreso.
# 286 Closest Port Lincoln hotel is Port Lincoln.
# 287 Closest Agios Vasileios hotel is Agios Vasileios.
# 288 Closest Kumul hotel is Hami.
# 289 Closest Longyearbyen hotel is Longyearbyen.
# 290 Closest Marzuq hotel is Al Hujayrah.
# 291 Closest Cherskiy hotel is Chersky.
# 292 Closest Muromtsevo hotel is Muromtsevo.
# 293 Closest Victoria Point hotel is Brisbane.
# 294 Closest Gambiran hotel is Pamotan.
# 295 Closest Nanton hotel is Nanton.
# 297 Closest Doba hotel is Doba.
# 298 Closest Abu Samrah hotel is Suruj.
# 299 Closest Gushikawa hotel is Okinawa.
# 300 Closest Los Llanos de Aridane hotel is Los Llanos.
# 301 Closest Byron Bay hotel is Byron Bay.
# 302 Closest Qandala hotel is Qandala.
# 303 Closest Kokemäki hotel is Kokemäki.
# 304 Closest Narón hotel is Ferrol.
# 305 Closest Ponta do Sol hotel is Ribeira Brava.
# 306 Closest Canary Islands hotel is Santa Brígida.
# 308 Closest Whitehorse hotel is Whitehorse.
# 309 Closest Vao hotel is Vao.
# 310 Closest Padang hotel is Padang.
# 311 Closest Gresham hotel is Portland.
# 312 Closest Jiwani hotel is Jiwani.
# 313 Closest Kiunga hotel is Kiunga.
# 314 Closest San Andrés hotel is San Andrés.
# 315 Closest Flinders hotel is Wollongong.
# 316 Closest Beloha hotel is Beloha.
# 317 Closest Dwārka hotel is Dwarka.
# 318 Closest Chipiona hotel is Sanlúcar de Barrameda.
# 319 Closest Bacolod City hotel is Bacolod.
# 320 Closest Stawell hotel is Stawell.
# 321 Closest Asilah hotel is Asilah.
# 322 Closest Hong Kong hotel is Hong Kong.
# 323 Closest Wau hotel is Wau.
# 324 Closest Steamboat Springs hotel is Steamboat Springs.
# 325 Closest Dicabisagan hotel is Ilagan.
# 326 Closest Afikpo hotel is Afikpo.
# 327 Closest Saint-Pierre hotel is Saint Pierre.
# 329 Closest Kosino hotel is Zuyevka.
# 330 Closest Brae hotel is Brae.
# 331 Closest Sioux Lookout hotel is Sioux Lookout.
# 332 Closest Nova Odesa hotel is Nova Odesa.
# 333 Closest Barra de Tecoanapa hotel is Barra de Tecoanapa.
# 334 Closest Kamenka hotel is Kamenka.
# 335 Closest Venado Tuerto hotel is Venado Tuerto.
# 336 Closest Nabire hotel is Nabire.
# 337 Closest Cayenne hotel is Cayenne.
# 338 Closest Selishche hotel is Selishche.
# 339 Closest Lakeville hotel is Lakeville.
# 340 Closest Makkah al Mukarramah hotel is Makkah al-Mukarramah.
# 341 Closest Seoul hotel is Seoul.
# 342 Closest Aripuanã hotel is Aripuanã.
# 343 Closest Kuala Terengganu hotel is Kuala Terengganu.
# 344 Closest Yenagoa hotel is Yenagoa.
# 345 Closest Zaozyornoye hotel is Yevpatoriya.
# 346 Closest Tazovsky hotel is Tazovskii.
# 347 Closest Chapais hotel is Chapais.
# 348 Closest Vila Franca do Campo hotel is Vila Franca do Campo.
# 349 Closest Vilyuysk hotel is Viliuisk.
# 350 Closest Chimbote hotel is Chimbote.
# 351 Closest Marawi hotel is Marawi City.
# 352 Closest Kashary hotel is Kashary.
# 353 Closest Mandalay hotel is Mandalay.
# 354 Closest Ostrovnoy hotel is Ostrovnoy.
# 355 Closest Bengkulu hotel is Bengkulu.
# 356 Closest Vrangel' hotel is Nakhodka.
# 357 Closest Laichow hotel is Yantai.
# 358 Closest Nantucket hotel is Nantucket.
# 359 Closest Alta Floresta hotel is Alta Floresta.
# 360 Closest Burnie hotel is Burnie.
# 361 Closest Kamaishi hotel is Kamaishi.
# 363 Closest Dunedin hotel is Dunedin.
# 364 Closest Olinda hotel is Olinda.
# 365 Closest Sedona hotel is Sedona.
# 366 Closest Torbay hotel is St. John's.
# 367 Closest Salalah hotel is Salalah.
# 368 Closest Port Moresby hotel is Port Moresby.
# 369 Closest Amapá hotel is Teresinha.
# 370 Closest Bariloche hotel is San Carlos de Bariloche.
# 371 Closest Flin Flon hotel is Flin Flon.
# 372 Closest Mahébourg hotel is Mahebourg.
# 373 Closest San Quintín hotel is Lázaro Cárdenas.
# 374 Closest Faya hotel is Faya.
# 375 Closest Okhotsk hotel is Okhotsk.
# 376 Closest Turukhansk hotel is Turukhansk.
# 377 Closest Lagoa hotel is Santa Cruz Da Graciosa.
# 378 Closest Matadi hotel is Matadi.
# 379 Closest Russell hotel is Russell County High School.
# 380 Closest Sármellék hotel is Keszthely.
# 381 Closest Hauterive hotel is Vichy.
# 382 Closest Mishan hotel is Jixi.
# 383 Closest Camacha hotel is Vila Baleira.
# 384 Closest Quatis hotel is Porto Real.
# 385 Closest Abancay hotel is Abancay.
# 386 Closest Oranjemund hotel is Oranjemund.
# 387 Closest Derzhavīnsk hotel is Derzhavinsk.
# 388 Closest Kiruna hotel is Kiruna.
# 389 Closest Norman hotel is Norman.
# 390 Closest Hergla hotel is Hergla.
# 391 Closest Polasara hotel is Polasara.
# 392 Closest Karakol hotel is Karakol.
# 393 Closest Ocean City hotel is Egg Harbor Township.
# 394 Closest Amahai hotel is Amahai.
# 395 Closest Hastings hotel is Hastings.
# 396 Closest Tuatapere hotel is Tuatapere.
# 397 Closest Puerto Colombia hotel is Sabanilla Montecarmelo.
# 398 Closest Kaeo hotel is Kaeo.
# 399 Closest Kishanganj hotel is Kishanganj.
# 400 Closest Kerman hotel is Kerman.
# 401 Closest Le Moule hotel is Sainte-Anne.
# 402 Closest Padampur hotel is Padampur.
# 403 Closest Luganville hotel is Luganville.
# 404 Closest Tuy Hoa hotel is Tuy Hòa.
# 405 Closest Concarneau hotel is Concarneau.
# 406 Closest Alofi hotel is Alofi.
# 407 Closest Lompoc hotel is Lompoc.
# 408 Closest Tucupita hotel is Tucupita.
# 409 Closest Bobo-Dioulasso hotel is Bobo-Dioulasso.
# 410 Closest Buala hotel is Buala.
# 411 Closest Isangel hotel is Isangel.
# 412 Closest Alexandria hotel is Alexandria.
# 413 Closest Novodugino hotel is Novodugino.
# 414 Closest At-Bashi hotel is At-Bashi.
# 415 Closest Danjiangkou hotel is Xiangyang.
# 416 Closest Santiago del Estero hotel is Santiago del Estero.
# 417 Closest Akdağmadeni hotel is Akdağmadeni.
# 418 Closest Kota Bharu hotel is Kota Bharu.
# 419 Closest Eston hotel is Eston.
# 420 Closest Jalu hotel is Jalu.
# 421 Closest Payo hotel is Keboer.
# 422 Closest Sandpoint hotel is Sandpoint.
# 423 Closest Nizhniy Tsasuchey hotel is Nizhnii Tsasuchei.
# 424 Closest Egvekinot hotel is Egvekinot.
# 425 Closest Kamen'-na-Obi hotel is Kamen-na-Obi.
# 426 Closest Novy Urengoy hotel is Novy Urengoy.
# 427 Closest Mattru hotel is Bandajuma.
# 428 Closest Manokwari hotel is Manokwari.
# 429 Closest Qasigiannguit hotel is Qasigiannguit.
# 430 Closest Touros hotel is Touros.
# 431 Closest Asău hotel is Comănești.
# 432 Closest Dutse hotel is Dutse.
# 433 Closest Kloulklubed hotel is Klouklubed.
# Missing field...skipping 434 Belaya Gora
# 435 Closest Arman' hotel is Arman'.
# 436 Closest Boyolangu hotel is Tulungagung.
# 437 Closest Pandan hotel is Pandan.
# 438 Closest Sur hotel is Sur.
# 439 Closest Magistral'nyy hotel is Magistral'nyy.
# 440 Closest Souillac hotel is Souillac.
# 441 Closest Leh hotel is Leh.
# 442 Closest Sompeta hotel is Sompeta.
# 443 Closest Laas hotel is Schlanders.
# 444 Closest Trincomalee hotel is Trincomalee.
# 445 Closest Zihuatanejo hotel is Zihuatanejo.
# 446 Closest La Rioja hotel is San Román de Cameros.
# 447 Closest Paamiut hotel is Paamiut.
# 448 Closest Ribeira Brava hotel is Câmara De Lobos.
# 449 Closest Morant Bay hotel is Morant Bay.
# 450 Closest Tyssedal hotel is Odda.
# 451 Closest Fairview hotel is New York.
# 452 Closest Morondava hotel is Morondava.
# 453 Closest Neuquén hotel is Neuquen.
# 454 Closest Aguié hotel is Aguié.
# 455 Closest Ţahţā hotel is Tahta.
# 456 Closest Porkhov hotel is Porkhov.
# 457 Closest Shawville hotel is Shawville.
# 458 Closest Umluj hotel is Umluj.
# 459 Closest Neiafu hotel is Neiafu.
# 460 Closest Mahibadhoo hotel is Omadhoo.
# 461 Closest Oodweyne hotel is Oodweyne.
# 462 Closest Maniwaki hotel is Maniwaki.
# 463 Closest Nelson Bay hotel is Nelson Bay - Corlette.
# 464 Closest Kangaatsiaq hotel is Kangaatsiaq.
# 465 Closest Waipawa hotel is Tora.
# 466 Closest Mahon hotel is Mahón.
# 467 Closest Viedma hotel is Viedma.
# 468 Closest Partenit hotel is Hurzuf.
# 469 Closest Telêmaco Borba hotel is Telêmaco Borba.
# 470 Closest Fukuechō hotel is Goto.
# 471 Closest Grindavik hotel is Grindavik.
# 472 Closest Luanda hotel is Luanda.
# 473 Closest Santa Isabel hotel is Santa Isabel.
# 474 Closest Salme hotel is Jharlang.
# 475 Closest Rawson hotel is Rawson.
# 476 Closest Novikovo hotel is Sumarokov.
# 477 Closest Atasū hotel is Atasu.
# 478 Closest Grand Gaube hotel is Goodlands.
# 479 Closest Fairbanks hotel is Fairbanks.
# 480 Closest Namatanai hotel is Namatanai.
# 481 Closest Saint-Joseph hotel is Saint Joseph.
# 482 Closest Hatillo hotel is Camuy.
# 483 Closest Ossora hotel is Ossora.
# 484 Closest Yeppoon hotel is Yeppoon.
# Missing field...skipping 485 Dukat
# 486 Closest Itarema hotel is Itarema.
# 487 Closest Gemena hotel is Gemena.
# 488 Closest Neryungri hotel is Neryungri.
# 489 Closest Kamloops hotel is Kamloops.
# 490 Closest Coquimbo hotel is Coquimbo.
# 492 Closest Pombas hotel is Sinagoga.
# 493 Closest Prescott hotel is Prescott.
# 494 Closest Laguna hotel is Sacramento.
# 495 Closest Sirte hotel is Sirte.
# 496 Closest Nuuk hotel is Nuuk.
# 497 Closest Ahipara hotel is Ahipara.
# 498 Closest Powell River hotel is Powell River.
# 499 Closest Papara hotel is Papara.
# 500 Closest Anadyr hotel is Anadyr.
# 501 Closest Ishigaki hotel is Ishigaki.
# 502 Closest Bubaque hotel is Bubaque.
# 504 Closest San Policarpo hotel is Oras.
# 505 Closest Sørland hotel is Sørland.
# 506 Closest Freetown hotel is Freetown.
# 507 Closest Dillon hotel is Dillon.
# 508 Closest Cabinda hotel is Cabinda.
# 509 Closest Izmail hotel is Izmail.
# 510 Closest Labuan hotel is Labuan.
# 511 Closest Kutum hotel is Kutum.
# 512 Closest Le Port hotel is Saint-Paul.
# 513 Closest Gizo Government Station hotel is Gizo.
# 514 Closest Mayo hotel is Mayo.
# 515 Closest Kingussie hotel is Newtonmore.
# 516 Closest Puerto Nariño hotel is Puerto Nariño.
# 517 Closest Cascais hotel is Cascais.
# 518 Closest Makat hotel is Makat.
# 519 Closest Cham hotel is Zug.
# 520 Closest Ayní hotel is Ayni.
# 521 Closest Palmer hotel is Palmer.
# 522 Closest Poya hotel is Poya.
# 523 Closest General Pico hotel is General Pico.
# 524 Closest Brooks hotel is Brooks.
# 525 Closest Abu Dhabi hotel is Abu Dhabi.
# 526 Closest Pachino hotel is Pachino.
# 527 Closest Puro hotel is Aroroy.
# 528 Closest Ventspils hotel is Ventspils.
# 529 Closest Manggar hotel is Manggar.
# 530 Closest Vysokogornyy hotel is Vysokogorny.
# 531 Closest Yar-Sale hotel is Yar-Sale.
# 532 Closest Qui Nhon hotel is Qui Nhơn.
# 533 Closest Jalingo hotel is Jalingo.
# 534 Closest Jiayuguan City hotel is Jiayuguan City.
# 535 Closest Lata hotel is Coimbra.
# 536 Closest Saryozek hotel is Saryozek.
# 537 Closest Batagay-Alyta hotel is Batagai-Alyta.
# 538 Closest Morehead hotel is Central City.
# 539 Closest Belyy Yar hotel is Belyi Yar.
# 540 Closest Kyra hotel is Kyra.

# %%
hotel_df.head(50)
# Out:
#                  City      Lat       Lng  Max temp    Temp  Humidity  \
# 0             Kavieng  -2.5744  150.7967     80.69   80.69        82
# 1      Saint-Philippe -21.3585   55.7679     86.11   83.97        72
# 2              Yulara -25.2406  130.9889    109.24  109.24         8
# 3            Hermanus -34.4187   19.2345     89.91   78.80        42
# 4            Khatanga  71.9667  102.5000    -39.32  -39.32       100
# 5             Trstená  49.3610   19.6125     35.20   31.98        87
# 6            Takaungu  -3.6837   39.8566     87.89   87.89        65
# 7             Mataura -46.1927  168.8643     57.47   57.47        67
# 8   Saint Paul Harbor  57.7900 -152.4072     30.90   30.90        76
# 9             Newport  51.5877   -2.9984     47.55   46.36        90
# 10            Melilla  35.2937   -2.9383     59.38   59.38        82
# 11       Punta Arenas -53.1500  -70.9167     48.16   48.16        86
# 12            Aklavik  68.2191 -135.0107    -12.17  -12.17       100
# 13             Carnot   4.9409   15.8665     94.37   94.37        18
# 14               Chui -33.6971  -53.4616     66.52   66.52        70
# 15          Hithadhoo  -0.6000   73.0833     83.19   83.19        71
# 16              Guane  22.2025  -84.0875     70.66   70.66        94
# 17        Salinópolis  -0.6136  -47.3561     81.64   81.64        75
# 18              Vaini -21.2000 -175.2000     78.96   78.96        89
# 19             Bethel  41.3712  -73.4140     42.10   39.29        64
# 20            Rikitea -23.1203 -134.9692     75.69   75.69        80
# 21       Tirukkoyilur  11.9500   79.2000     82.35   82.35        53
# 22          Geraldton -28.7667  114.6000     72.12   72.01        56
# 23             Avarua -21.2078 -159.7750     78.85   78.85        83
# 24            Batouri   4.4333   14.3667     91.27   91.27        21
# 25            Fortuna  40.5982 -124.1573     39.47   37.31       100
# 26             Rājula  21.0500   71.4333     81.91   81.91        37
# 27            Ushuaia -54.8000  -68.3000     47.86   47.86        87
# 29           Tessalit  20.1986    1.0114     76.01   76.01        13
# 30          Jamestown  42.0970  -79.2353     33.53   32.31        97
# 31             Talara  -4.5772  -81.2719     68.76   68.76        83
# 32      Mar del Plata -38.0023  -57.5575     68.09   67.32        92
# 33     Guerrero Negro  27.9769 -114.0611     57.13   57.13        56
# 34          Carnarvon -24.8667  113.6333     77.07   77.07        61
# 35              Airai  -8.9266  125.4092     64.87   64.87        90
# 36             Albany  42.6001  -73.9662     35.80   33.33        74
# 37         Vila Velha -20.3297  -40.2925     75.94   75.94        92
# 38            Qaanaaq  77.4840  -69.3632     -8.84   -8.84        76
# 39          Busselton -33.6500  115.3333     67.08   66.04        52
# 40           Kirakira -10.4544  161.9205     79.41   79.41        84
# 41             Shingū  33.7333  135.9833     40.19   40.19        84
# 42            Boyuibe -20.4167  -63.2833     70.18   70.18        56
# 43            Hualmay -11.0964  -77.6139     65.80   65.80        92
# 44        Broken Hill -31.9500  141.4333    103.71  103.71        11
# 45             Barrow  71.2906 -156.7887     -9.38   -9.38        77
# 46              Quime -16.9833  -67.2167     49.89   49.89        94
# 47        Yellowknife  62.4560 -114.3525    -18.58  -19.86        86
# 48         Bredasdorp -34.5322   20.0403     78.28   70.92        56
# 49             Nemuro  43.3236  145.5750     16.23   16.23        54
# 50             Faanui -16.4833 -151.7500     80.83   80.83        71
#
#     Cloudiness  Windspeed Country        Date       Hotel Name
# 0          100       7.56      PG  1639820794          Kavieng
# 1           16       2.01      RE  1639821072   Saint-Philippe
# 2           15      10.36      AU  1639820871        Petermann
# 3           10      13.42      ZA  1639821073         Hermanus
# 4           65       3.13      RU  1639820909         Chatanga
# 5           89       7.00      SK  1639821073          Trstená
# 6           89       7.07      KE  1639821073           Kilifi
# 7          100       2.21      NZ  1639821074             Gore
# 8          100       5.48      US  1639820826           Kodiak
# 9           61      11.92      GB  1639821054          Newport
# 10          75      11.50      ES  1639821074          Melilla
# 11           0       3.33      CL  1639821074     Punta Arenas
# 12          93       3.69      CA  1639821075          Aklavik
# 13          94       5.08      CF  1639821075           Carnot
# 14           0       7.49      UY  1639821075             Chuy
# 15          71       5.28      MV  1639821075        Addu City
# 16          98       7.23      CU  1639821076            Guane
# 17          97      10.42      BR  1639821076      Salinópolis
# 18          20       2.30      TO  1639821076       Nukuhetulu
# 19         100       4.43      US  1639821077          Danbury
# 20          99      18.39      PF  1639821077          Rikitea
# 21          76      11.56      IN  1639821077     Thirukoilure
# 22          40      14.97      AU  1639821078        Geraldton
# 23          75       2.30      CK  1639821078  Avarua District
# 24          97       3.85      CM  1639821078          Batouri
# 25           1       9.22      US  1639821078          Fortuna
# 26           0      11.21      IN  1639821078           Rajula
# 27          20       0.00      AR  1639821080          Ushuaia
# 29          38      20.96      ML  1639820994       Achemelmel
# 30          90       3.00      US  1639821080        Jamestown
# 31          76      13.02      PE  1639821081           Talara
# 32           0       5.01      AR  1639821081    Mar del Plata
# 33           5       1.39      MX  1639821081   Guerrero Negro
# 34           0      21.85      AU  1639821081        Carnarvon
# 35          99       2.98      TL  1639820793           Atsabe
# 36         100       3.00      US  1639821082    Voorheesville
# 37          75       7.00      BR  1639821082       Vila Velha
# 38          65       7.54      GL  1639821082          Qaanaaq
# 39          41      15.68      AU  1639821082        Busselton
# 40         100       4.21      SB  1639821083          Arohane
# 41          51       4.88      JP  1639821053           Shingu
# 42          18       3.83      BO  1639821083          Boyuibe
# 43          51       7.92      PE  1639821084           Huacho
# 44          23      12.66      AU  1639821084      Broken Hill
# 45          90      20.71      US  1639821084        Utqiagvik
# 46         100       0.54      BO  1639821084            Quime
# 47          75      12.66      CA  1639821135      Yellowknife
# 48           5      18.41      ZA  1639821135       Bredasdorp
# 49          19      23.87      JP  1639821135           Nemuro
# 50          99      13.22      PF  1639821136          Vaitape

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %% [markdown]
# # Add marker layer on top of heat map
# # Display figure

# %%
# Create a marker_layer using the hotel_info to fill the info box
fig = gmaps.figure()
markers = gmaps.marker_layer(locations,
    info_box_content=hotel_info)                        
fig.add_layer(markers)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
